# %%
from bing_image_downloader import downloader

# %%
downloader.download("Hotel Restaurant Kitchen", limit=70,  output_dir='hotel')
# Out:
# [%] Downloading Images to c:\Users\kumar\OneDrive\Desktop\ml\image_classifier\hotel\Hotel Restaurant Kitchen
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 34 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.hotelierindia.com/public/styles/full_img_sml/public/images/2020/02/14/shutterstock_1560097280.jpg?itok=2VsIHH55
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://akyatrading.com/wp-content/uploads/2017/01/Agreeable-Commercial-Kitchen-Fancy-Inspirational-Kitchen-Decorating-with-Commercial-Kitchen.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/22/90/bb/2290bbfb65881852488f5f2218a3d889.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/KO1TIIWOAY0/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.hirerush.com/blog/wp-content/uploads/2018/04/restaurant-kitchen-cover.jpg
# [%] File Downloaded !
#
# ...
